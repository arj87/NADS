# %%
##  the purpose of this code is to determine which features to use in the machine learning phase.
##  for this purpose, the importance weights of the attacks are calculated.
##  this calculation was made using sklearn-RandomForestRegressor.

##  the some codes parts used for calculation and graphing are taken from the following site.
##  http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

def folder(f_name): 
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")
        


csv_files=os.listdir("attacks")


main_labels = [
    "Destination Port", "Flow Duration", "Total Fwd Packets", "Total Backward Packets", 
    "Total Length of Fwd Packets", "Total Length of Bwd Packets", "Fwd Packet Length Max",
    "Fwd Packet Length Min", "Fwd Packet Length Mean", "Fwd Packet Length Std", 
    "Bwd Packet Length Max", "Bwd Packet Length Min", "Bwd Packet Length Mean", 
    "Bwd Packet Length Std", "Flow Bytes/s", "Flow Packets/s", "Flow IAT Mean", 
    "Flow IAT Std", "Flow IAT Max", "Flow IAT Min", "Fwd IAT Total", "Fwd IAT Mean", 
    "Fwd IAT Std", "Fwd IAT Max", "Fwd IAT Min", "Bwd IAT Total", "Bwd IAT Mean", 
    "Bwd IAT Std", "Bwd IAT Max", "Bwd IAT Min", "Fwd PSH Flags", "Bwd PSH Flags", 
    "Fwd URG Flags", "Bwd URG Flags", "Fwd Header Length", "Bwd Header Length", 
    "Fwd Packets/s", "Bwd Packets/s", "Min Packet Length", "Max Packet Length", 
    "Packet Length Mean", "Packet Length Std", "Packet Length Variance", 
    "FIN Flag Count", "SYN Flag Count", "RST Flag Count", "PSH Flag Count", 
    "ACK Flag Count", "URG Flag Count", "CWE Flag Count", "ECE Flag Count", 
    "Down/Up Ratio", "Average Packet Size", "Avg Fwd Segment Size", 
    "Avg Bwd Segment Size", "Fwd Header Length.1", "Fwd Avg Bytes/Bulk", "Fwd Avg Packets/Bulk", 
    "Fwd Avg Bulk Rate", "Bwd Avg Bytes/Bulk", "Bwd Avg Packets/Bulk", 
    "Subflow Fwd Packets", "Subflow Fwd Bytes", "Subflow Bwd Packets", 
    "Subflow Bwd Bytes", "Init_Win_bytes_forward", "Init_Win_bytes_backward", 
    "act_data_pkt_fwd", "min_seg_size_forward", "Active Mean", "Active Std", 
    "Active Max", "Active Min", "Idle Mean", "Idle Std", "Idle Max", "Idle Min", 
    "label"  
]

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feaure_pics/")
for j in csv_files:
    df=pd.read_csv("./attacks/"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["label"]:
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)           
    df["label"]=attack_or_not

    y = df["label"].values
    del df["label"]
    X = df.values
    
    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0
   

    
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar()
    
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break     
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",bbox_inches='tight', format = 'pdf')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")

    
print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Destination Port               0.989133
# Total Fwd Packets              0.000696
# Flow IAT Min                   0.000458
# Fwd Packet Length Max          0.000166
# Bwd Packet Length Max          0.000133
# Total Length of Fwd Packets    0.000128
# Total Length of Bwd Packets    0.000081
# Bwd Packet Length Std          0.000080
# Total Backward Packets         0.000073
# Flow IAT Max                   0.000049
# Flow Duration                  0.000041
# Fwd Packet Length Mean         0.000036
# Flow Packets/s                 0.000031
# Bwd Packet Length Mean         0.000024
# Flow IAT Mean                  0.000022
# Bwd Packet Length Min          0.000019
# Flow IAT Std                   0.000003
# Fwd Packet Length Std          0.000002
# Flow Bytes/s                   0.000001
# Fwd Packet Length Min          0.000000
#
#
#
# FTP-Patator=["Destination Port","Total Fwd Packets","Flow IAT Min","Fwd Packet Length Max","Bwd Packet Length Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                               importance
# Features
# Total Length of Fwd Packets    0.361200
# Flow Bytes/s                   0.315550
# Destination Port               0.002270
# Bwd Packet Length Std          0.000339
# Flow Duration                  0.000264
# Flow IAT Mean                  0.000231
# Flow Packets/s                 0.000191
# Flow IAT Max                   0.000170
# Fwd Packet Length Max          0.000090
# Total Fwd Packets              0.000069
# Flow IAT Min                   0.000065
# Bwd Packet Length Mean         0.000057
# Total Length of Bwd Packets    0.000047
# Fwd Packet Length Std          0.000045
# Bwd Packet Length Min          0.000042
# Bwd Packet Length Max          0.000035
# Flow IAT Std                   0.000018
# Total Backward Packets         0.000010
# Fwd Packet Length Mean         0.000008
# Fwd Packet Length Min          0.000003
#
#
#
# PortScan=["Total Length of Fwd Packets","Flow Bytes/s","Destination Port","Bwd Packet Length Std","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow Packets/s                 0.591604
# Fwd Packet Length Min          0.111771
# Flow IAT Mean                  0.059952
# Bwd Packet Length Std          0.041252
# Bwd Packet Length Mean         0.033108
# Destination Port               0.028332
# Bwd Packet Length Max          0.004321
# Total Length of Bwd Packets    0.004279
# Flow IAT Min                   0.002813
# Total Fwd Packets              0.000906
# Fwd Packet Length Max          0.000710
# Fwd Packet Length Mean         0.000699
# Total Length of Fwd Packets    0.000585
# Fwd Packet Length Std          0.000489
# Flow Bytes/s                   0.000432
# Bwd Packet Length Min          0.000382
# Flow Duration                  0.000202
# Flow IAT Max                   0.000195
# Flow IAT Std                   0.000032
# Total Backward Packets         0.000020
#
#
#
# DoS Slowhttptest=["Flow Packets/s","Fwd Packet Length Min","Flow IAT Mean","Bwd Packet Length Std","Bwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Destination Port                    0.0
# Flow Duration                       0.0
# Flow IAT Max                        0.0
# Flow IAT Std                        0.0
# Flow IAT Mean                       0.0
# Flow Packets/s                      0.0
# Flow Bytes/s                        0.0
# Bwd Packet Length Std               0.0
# Bwd Packet Length Mean              0.0
# Bwd Packet Length Min               0.0
# Bwd Packet Length Max               0.0
# Fwd Packet Length Std               0.0
# Fwd Packet Length Mean              0.0
# Fwd Packet Length Min               0.0
# Fwd Packet Length Max               0.0
# Total Length of Bwd Packets         0.0
# Total Length of Fwd Packets         0.0
# Total Backward Packets              0.0
# Total Fwd Packets                   0.0
# Flow IAT Min                        0.0
#
#
#
# Web Attack=["Destination Port","Flow Duration","Flow IAT Max","Flow IAT Std","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Hulk importance list:
# DoS Hulk
#                                 importance
# Features
# Bwd Packet Length Std        5.851904e-01
# Destination Port             1.621295e-01
# Flow IAT Mean                4.997509e-02
# Flow IAT Std                 2.328917e-03
# Flow IAT Min                 4.078319e-04
# Total Backward Packets       2.562702e-04
# Flow Duration                1.537370e-04
# Flow Packets/s               1.318910e-04
# Flow Bytes/s                 6.204822e-05
# Flow IAT Max                 5.696273e-05
# Total Length of Bwd Packets  2.766801e-05
# Total Fwd Packets            1.283045e-05
# Fwd Packet Length Max        9.621716e-06
# Bwd Packet Length Mean       9.146411e-06
# Fwd Packet Length Mean       8.028570e-06
# Bwd Packet Length Min        7.648082e-06
# Fwd Packet Length Std        7.410054e-06
# Bwd Packet Length Max        5.163707e-06
# Total Length of Fwd Packets  2.163507e-06
# Fwd Packet Length Min        6.013154e-07
#
#
#
# DoS Hulk=["Bwd Packet Length Std","Destination Port","Flow IAT Mean","Flow IAT Std","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Total Backward Packets            0.068
# Total Fwd Packets                 0.064
# Bwd Packet Length Std             0.056
# Bwd Packet Length Max             0.052
# Total Length of Bwd Packets       0.040
# Bwd Packet Length Mean            0.040
# Flow Duration                     0.016
# Flow IAT Min                      0.016
# Total Length of Fwd Packets       0.016
# Fwd Packet Length Max             0.008
# Fwd Packet Length Mean            0.000
# Fwd Packet Length Std             0.000
# Fwd Packet Length Min             0.000
# Bwd Packet Length Min             0.000
# Flow Bytes/s                      0.000
# Flow Packets/s                    0.000
# Flow IAT Mean                     0.000
# Flow IAT Std                      0.000
# Flow IAT Max                      0.000
# Destination Port                  0.000
#
#
#
# Heartbleed=["Total Backward Packets","Total Fwd Packets","Bwd Packet Length Std","Bwd Packet Length Max","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Flow IAT Mean                  0.484124
# Bwd Packet Length Mean         0.108928
# Destination Port               0.099097
# Total Length of Bwd Packets    0.010948
# Flow IAT Min                   0.002117
# Bwd Packet Length Max          0.000859
# Bwd Packet Length Std          0.000672
# Fwd Packet Length Max          0.000523
# Flow IAT Max                   0.000477
# Fwd Packet Length Std          0.000373
# Flow Bytes/s                   0.000350
# Fwd Packet Length Mean         0.000333
# Flow IAT Std                   0.000330
# Total Length of Fwd Packets    0.000276
# Total Backward Packets         0.000251
# Flow Duration                  0.000213
# Flow Packets/s                 0.000192
# Total Fwd Packets              0.000180
# Fwd Packet Length Min          0.000013
# Bwd Packet Length Min          0.000001
#
#
#
# DoS slowloris=["Flow IAT Mean","Bwd Packet Length Mean","Destination Port","Total Length of Bwd Packets","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Bot importance list:
# Bot
#                               importance
# Features
# Destination Port               0.564588
# Bwd Packet Length Mean         0.122263
# Flow IAT Min                   0.008718
# Flow IAT Std                   0.002661
# Flow IAT Max                   0.000627
# Flow Duration                  0.000533
# Flow IAT Mean                  0.000494
# Flow Packets/s                 0.000456
# Flow Bytes/s                   0.000268
# Fwd Packet Length Mean         0.000249
# Total Length of Bwd Packets    0.000189
# Total Length of Fwd Packets    0.000167
# Total Backward Packets         0.000141
# Fwd Packet Length Std          0.000135
# Total Fwd Packets              0.000134
# Fwd Packet Length Max          0.000076
# Fwd Packet Length Min          0.000069
# Bwd Packet Length Max          0.000065
# Bwd Packet Length Std          0.000042
# Bwd Packet Length Min          0.000019
#
#
#
# Bot=["Destination Port","Bwd Packet Length Mean","Flow IAT Min","Flow IAT Std","Flow IAT Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Total Length of Fwd Packets    0.230754
# Destination Port               0.174943
# Flow IAT Max                   0.041479
# Flow Duration                  0.026754
# Fwd Packet Length Mean         0.023093
# Total Fwd Packets              0.021047
# Fwd Packet Length Max          0.015057
# Total Backward Packets         0.005250
# Flow IAT Std                   0.004471
# Flow IAT Mean                  0.002807
# Bwd Packet Length Std          0.002790
# Flow Bytes/s                   0.002533
# Bwd Packet Length Max          0.002121
# Bwd Packet Length Mean         0.001830
# Fwd Packet Length Std          0.001746
# Flow Packets/s                 0.001577
# Flow IAT Min                   0.001281
# Fwd Packet Length Min          0.000723
# Total Length of Bwd Packets    0.000520
# Bwd Packet Length Min          0.000236
#
#
#
# Infiltration=["Total Length of Fwd Packets","Destination Port","Flow IAT Max","Flow Duration","Fwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS1 importance list:
# DDoS1
#                               importance
# Features
# Bwd Packet Length Std          0.549723
# Total Backward Packets         0.086520
# Destination Port               0.014487
# Fwd Packet Length Max          0.002785
# Total Length of Fwd Packets    0.002259
# Fwd Packet Length Std          0.000221
# Bwd Packet Length Min          0.000217
# Flow Bytes/s                   0.000113
# Total Fwd Packets              0.000045
# Bwd Packet Length Mean         0.000045
# Fwd Packet Length Min          0.000045
# Flow Duration                  0.000043
# Flow IAT Min                   0.000043
# Bwd Packet Length Max          0.000041
# Flow IAT Max                   0.000038
# Flow IAT Std                   0.000036
# Total Length of Bwd Packets    0.000033
# Flow IAT Mean                  0.000027
# Flow Packets/s                 0.000023
# Fwd Packet Length Mean         0.000007
#
#
#
# DDoS1=["Bwd Packet Length Std","Total Backward Packets","Destination Port","Fwd Packet Length Max","Total Length of Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Bwd Packet Length Std          0.582264
# Flow IAT Min                   0.278225
# Destination Port               0.046632
# Flow IAT Mean                  0.043154
# Flow IAT Std                   0.003666
# Fwd Packet Length Min          0.001263
# Flow Bytes/s                   0.000925
# Total Backward Packets         0.000839
# Flow Packets/s                 0.000755
# Flow IAT Max                   0.000711
# Flow Duration                  0.000537
# Total Length of Fwd Packets    0.000249
# Total Length of Bwd Packets    0.000237
# Fwd Packet Length Max          0.000195
# Fwd Packet Length Mean         0.000195
# Bwd Packet Length Max          0.000140
# Bwd Packet Length Mean         0.000021
# Fwd Packet Length Std          0.000018
# Total Fwd Packets              0.000017
# Bwd Packet Length Min          0.000016
#
#
#
# DoS GoldenEye=["Bwd Packet Length Std","Flow IAT Min","Destination Port","Flow IAT Mean","Flow IAT Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Destination Port               0.974339
# Total Fwd Packets              0.000053
# Flow Packets/s                 0.000051
# Flow Duration                  0.000044
# Flow IAT Mean                  0.000040
# Fwd Packet Length Min          0.000038
# Flow IAT Max                   0.000029
# Flow IAT Std                   0.000026
# Fwd Packet Length Mean         0.000025
# Flow Bytes/s                   0.000023
# Bwd Packet Length Max          0.000022
# Fwd Packet Length Max          0.000021
# Bwd Packet Length Mean         0.000020
# Total Length of Fwd Packets    0.000019
# Fwd Packet Length Std          0.000017
# Total Backward Packets         0.000016
# Total Length of Bwd Packets    0.000014
# Flow IAT Min                   0.000013
# Bwd Packet Length Std          0.000012
# Bwd Packet Length Min          0.000000
#
#
#
# SSH-Patator=["Destination Port","Total Fwd Packets","Flow Packets/s","Flow Duration","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Bwd Packet Length Std          0.549723
# Total Backward Packets         0.086520
# Destination Port               0.014487
# Fwd Packet Length Max          0.002785
# Total Length of Fwd Packets    0.002259
# Fwd Packet Length Std          0.000221
# Bwd Packet Length Min          0.000217
# Flow Bytes/s                   0.000113
# Total Fwd Packets              0.000045
# Bwd Packet Length Mean         0.000045
# Fwd Packet Length Min          0.000045
# Flow Duration                  0.000043
# Flow IAT Min                   0.000043
# Bwd Packet Length Max          0.000041
# Flow IAT Max                   0.000038
# Flow IAT Std                   0.000036
# Total Length of Bwd Packets    0.000033
# Flow IAT Mean                  0.000027
# Flow Packets/s                 0.000023
# Fwd Packet Length Mean         0.000007
#
#
#
# DDoS=["Bwd Packet Length Std","Total Backward Packets","Destination Port","Fwd Packet Length Max","Total Length of Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  4360.183657884598 seconds
